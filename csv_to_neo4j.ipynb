# %%
url='https://drive.google.com/file/d/192ezD599zWtoMhtNpd4ygNXZu37U0twr/view?usp=share_link'
url='https://drive.google.com/uc?id=' + url.split('/')[-2]
print(url)
df = pd.read_csv(url)
df
# Out:
# https://drive.google.com/uc?id=192ezD599zWtoMhtNpd4ygNXZu37U0twr
#    IATA_CODE                       AIRLINE
# 0         UA         United Air Lines Inc.
# 1         AA        American Airlines Inc.
# 2         US               US Airways Inc.
# 3         F9        Frontier Airlines Inc.
# 4         B6               JetBlue Airways
# 5         OO         Skywest Airlines Inc.
# 6         AS          Alaska Airlines Inc.
# 7         NK              Spirit Air Lines
# 8         WN        Southwest Airlines Co.
# 9         DL          Delta Air Lines Inc.
# 10        EV   Atlantic Southeast Airlines
# 11        HA        Hawaiian Airlines Inc.
# 12        MQ  American Eagle Airlines Inc.
# 13        VX                Virgin America

# %%
url='https://drive.google.com/file/d/1ud9I_9cl-rkl3K8pol5P28g2naTsWPnb/view?usp=share_link'
url='https://drive.google.com/uc?id=' + url.split('/')[-2]
print(url)
df = pd.read_csv(url)
df
# Out:
# https://drive.google.com/uc?id=1ud9I_9cl-rkl3K8pol5P28g2naTsWPnb
#   IATA_CODE                                       AIRPORT               CITY  \
# 0       SEA          Seattle-Tacoma International Airport            Seattle
# 1       PBI              Palm Beach International Airport    West Palm Beach
# 2       CLT       Charlotte Douglas International Airport          Charlotte
# 3       MIA                   Miami International Airport              Miami
# 4       ANC   Ted Stevens Anchorage International Airport          Anchorage
# 5       MSP  Minneapolis-Saint Paul International Airport        Minneapolis
# 6       CLT       Charlotte Douglas International Airport          Charlotte
# 7       DFW       Dallas/Fort Worth International Airport  Dallas-Fort Worth
#
#   STATE COUNTRY  LATITUDE  LONGITUDE
# 0    WA     USA  47.44898 -122.30931
# 1    FL     USA  26.68316  -80.09559
# 2    NC     USA  35.21401  -80.94313
# 3    FL     USA  25.79325  -80.29056
# ...

# %%
url='https://drive.google.com/file/d/1D5A11I0d5cK6pnI9hfGP5RhXnZiVawPJ/view?usp=share_link'
url='https://drive.google.com/uc?id=' + url.split('/')[-2]
print(url)
df = pd.read_csv(url)
print(','.join(["flight.{}=row.{}".format(x.lower(), x) for x in df.columns if x != 'FLIGHT_NUMBER']))
df
# Out:
# https://drive.google.com/uc?id=1D5A11I0d5cK6pnI9hfGP5RhXnZiVawPJ
# ...

# %%
df.iloc[3,:]
# Out:
# YEAR                     2015
# MONTH                       1
# DAY                         1
# DAY_OF_WEEK                 4
# AIRLINE                    AA
# FLIGHT_NUMBER             258
# TAIL_NUMBER            N3HYAA
# ORIGIN_AIRPORT            LAX
# DESTINATION_AIRPORT       MIA
# SCHEDULED_DEPARTURE        20
# DEPARTURE_TIME             15
# DEPARTURE_DELAY            -5
# TAXI_OUT                   15
# WHEELS_OFF                 30
# SCHEDULED_TIME            285
# ELAPSED_TIME              281
# AIR_TIME                  258
# DISTANCE                 2342
# WHEELS_ON                 748
# TAXI_IN                     8
# SCHEDULED_ARRIVAL         805
# ARRIVAL_TIME              756
# ARRIVAL_DELAY              -9
# DIVERTED                    0
# CANCELLED                   0
# CANCELLATION_REASON       NaN
# AIR_SYSTEM_DELAY          NaN
# SECURITY_DELAY            NaN
# AIRLINE_DELAY             NaN
# LATE_AIRCRAFT_DELAY       NaN
# WEATHER_DELAY             NaN
# ...
